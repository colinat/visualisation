# %% [markdown]
# # Choosing Plot Types and Custom Styles
# ---
#
# In this notebook, we'll recap on the visualisation lessons we'd learnt as well as learning some quick commands that you can use to change the style of your charts.

# %% [markdown]
# It's not always easy to decide how to best tell the story behind your data, thus we'll learn about the three board categories of charts to help with this.
#
# #### Trends
# A trend is defined as a pattern of change.
#
# + `sns.lineplot` - **Line charts** are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group
#
#
# #### Relationship
# There are many different chart types that you can use to understand relationships between variabls in your data.
#
# + `sns.barplot` - **Bar charts** are useful for comparing quantities corresponding to different groups.
# + `sns.heatmap` - **Heatmaps** can be used to find colour-coded patterns in tables of numbers.
# + `sns.scatterplot` - **Scatter plots** show the relationship between two continuous variables.
# + `sns.regplot` - including a **regression line** in the scatterplot makes it easier to see any linear relationship between two variables
# + `sns.lmplot` - This command is useful for drawing multiple regression lines, if the scatterplot contains multiple colour-coded groups.
# + `sns.swarmplot` - **Categorical scatterploots** show the relationship between a continuous variable and a categorical variable.
#
#
# #### Distribution
# We visualise distributions to show the possible values that we can expect to see in variable, along with how likely they are.
#
# + `sns.distplot` - **Histograms** show the distribution of a single numerical variable.
# + `sns.kdeplot` - **KDE plots** (or **2D KDE plots**) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
# + `sns.jointplot` - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable.

# %% [markdown]
# ## Changing styles with seaborn
#
# You

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

import warnings
warnings.filterwarnings("ignore")

# %%
spotify_data = pd.read_csv('examples/spotify_data_formatted.csv')

plt.figure(figsize=(16,6))

sns.lineplot(data=spotify_data)
plt.show()

# %% [markdown]
# We can quickly change the style of the figure to a different theme using `sns.set_style`

# %%
sns.set_style('dark')
plt.figure(figsize=(16,6))

sns.lineplot(data=spotify_data)
plt.show()

# %% [markdown]
# Seaborn has five different themes:
#
# + 'darkgrid'
# + 'whitegrid'
# + 'dark'
# + 'white'
# + 'ticks' (default)
#
# You can use `sns.set_style()` to change the theme
