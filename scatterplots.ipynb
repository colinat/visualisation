# %% [markdown]
# # Scatter Plots
# ---
#
# In this notebook, you'll learn about scatterplots. Scatterplots are generally useful tool to discover any prominent relationship between two variables in a quick glance.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# [Dataset](https://www.kaggle.com/mirichoi0218/insurance/home) used comprises data relating to healthcare insurance costs

# %%
insurance_data = pd.read_csv('examples/insurance.csv')
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Plotting the data
#
# To create a simple scatter plot, we use the `sns.scatterplot` command and specify the values for:
#
# + the horizontal x-axis (`x=insurance_data['bmi']`), and
# + the vertical y-axis (`y=insurance_data['charges']`).

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# The scatterplot is great for visualising relationship between two continous variables which - in this case - are body mass index (BMI) and insurance charges.
#
# The plot shows they are positively correlated, where customers with higher BMI typically also tend to pay more in insurance costs. (This pattern makes sense, since high BMI is typically associated with higher risk of chronic disease.)
#
# To double-check the strength of this relationship, you might like to add a regression line, or the line that best fits the data. We do this by changing the command to `sns.regplot`.

# %%
plt.figure(figsize=(10,6))

# adds a regression line in addition to scatter plot
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ## Color-coded scatter plots¶
#
# We can use scatter plots to display the relationships between (not two, but...) three variables! One way of doing this is by color-coding the points.
#
# For instance, to understand how smoking affects the relationship between BMI and insurance costs, we can color-code the points by 'smoker', and plot the other two columns ('bmi', 'charges') on the axes.

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# This scatter plot shows that while nonsmokers to tend to pay slightly more with increasing BMI, smokers pay MUCH more.
#
# To further emphasize this fact, we can use the `sns.lmplot` command to add two regression lines, corresponding to smokers and nonsmokers. (You'll notice that the regression line for smokers has a much steeper slope, relative to the line for nonsmokers!)

# %%
plt.figure(figsize=(10,6))

# adds regression lines to scatter plots. Unlike regplot, lmplot allows the hue parameter for division
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)

# %% [markdown]
# The `sns.lmplot` command above works slightly differently than the commands you have learned about so far:
#
# + Instead of setting `x=insurance_data['bmi']` to select the 'bmi' column in insurance_data, we set `x="bmi"` to specify the name of the column only.
# + Similarly, `y="charges"` and `hue="smoker"` also contain the names of columns.
# + We specify the dataset with data=insurance_data.

# %% [markdown]
# ## Swamplots (for categorical variable)
#
# Usually, we use scatter plots to highlight the relationship between two continuous variables (like "bmi" and "charges"). However, we can adapt the design of the scatter plot to feature a **categorical** variable (like "smoker") on one of the main axes. We'll refer to this plot type as a categorical scatter plot, and we build it with the `sns.swarmplot` command.

# %%
plt.figure(figsize=(10,6))

sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %% [markdown]
# Among other things, this plot shows us that:
#
# + on average, non-smokers are charged less than smokers, and
# + the customers who pay the most are smokers; whereas the customers who pay the least are non-smokers.

# %% [markdown]
# ## Scatterplot Matrix
#
# In exploratory data analysis, it's helpful to be able to look at all the scatterplots among a group of variables using scatterplot matrix or `sns.pairplot`:

# %%
plt.figure(figsize=(10,6))

sns.pairplot(insurance_data, diag_kind='kde')

# %% [markdown]
# In the code above:
#
# + `diag_kind='kde'`- used to determine kind of plots used for diagonal subplots (univariate analysis)
#
# The scatterplot matrix above shows there is somewhat some positive relationship between age and insurance charges at a glance.

# %% [markdown]
# Next up, we'll learn about [distribution plots](https://github.com/colintwh/visualisation/blob/master/distplots.ipynb)
